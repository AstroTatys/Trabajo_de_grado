# %% [markdown]
# Todos los datos que se usaron para la recreación de las curvas de rotación de las galaxias espirales fueron tomadas de:
# https://www.ioa.s.u-tokyo.ac.jp/~sofue/RC99/rc99.htm

# %%
#Librerias
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
import scipy.integrate as integrate
import scipy.special as special
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Constante para todas las galaxias.
global G
G = 6.67384E-11*1.9891E30*(1.0001044887813144157/3.086e19)**3 #[kpc^3/(Msun*s^3)]

# %%
#Datos.
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # **GALAXIAS TIPO Sb**

# %% [markdown]
# **MILKY WAY**

# %%
#Datos
radio,velc = np.loadtxt("0000.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc=velc*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R = np.linspace(radio[1],radio[-1],num=len(radio))  #[kpc]

#Grafica.
plt.plot(R,Velc*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.title("Milky Way")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("milky_way.png")

# %% [markdown]
# **NGC 0224**

# %%
#Datos
radio1,velc1 = np.loadtxt("0224.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc1 = velc1*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R1 = np.linspace(radio1[1],radio1[-1],num=len(radio1))  #[kpc]

#Grafica.
plt.plot(R1,Velc1*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 0224")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc0224.png")

# %% [markdown]
# **0891**

# %%
#Datos
radio2,velc2 = np.loadtxt("0891.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc2 = velc2*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R2 = np.linspace(radio2[1],radio2[-1],num=len(radio2))  #[kpc]

#Grafica.
plt.plot(R2,Velc2*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 0891")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc0891.png")

# %% [markdown]
#  **1068**

# %%
#Datos
radio3,velc3 = np.loadtxt("1068.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc3 = velc3*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R3 = np.linspace(radio3[1],radio3[-1],num=len(radio3))  #[kpc]

#Grafica.
plt.plot(R3,Velc3*(3.086e16/1.0001044887813144157),  ".", markersize=2, color="purple")

plt.title("NGC 1068")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc1068.png")

# %% [markdown]
# **1417**

# %%
#Datos
radio4,velc4 = np.loadtxt("1417.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc4 = velc4*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R4 = np.linspace(radio4[1],radio4[-1],num=len(radio4))  #[kpc]

#Grafica.
plt.plot(R4,Velc4*(3.086e16/1.0001044887813144157),  ".", markersize=2, color="purple")

plt.title("NGC 1417")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc1417.png")

# %% [markdown]
# **2590**

# %%
#Datos
radio5,velc5 = np.loadtxt("2590.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc5 = velc5*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R5 = np.linspace(radio5[1],radio5[-1],num=len(radio5))  #[kpc]

#Grafica.
plt.plot(R5,Velc5*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 2590")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc2590.png")

# %% [markdown]
# **2708**

# %%
#Datos
radio6,velc6 = np.loadtxt("2708.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc6 = velc6*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R6 = np.linspace(radio6[1],radio6[-1],num=len(radio6))  #[kpc]

#Grafica.
plt.plot(R6,Velc6*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 2708")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc2708.png")

# %% [markdown]
# **2841**

# %%
#Datos
radio7,velc7 = np.loadtxt("2841.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc7 = velc7*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R7 = np.linspace(radio7[1],radio7[-1],num=len(radio7))  #[kpc]

#Grafica.
plt.plot(R7,Velc7*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 2841")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc2841.png")

# %% [markdown]
# **3031**

# %%
#Datos
radio8,velc8 = np.loadtxt("3031.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc8 = velc8*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R8 = np.linspace(radio8[1],radio8[-1],num=len(radio8))  #[kpc]

#Grafica.
plt.plot(R8,Velc8*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 3031")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc3031.png")

# %% [markdown]
# **4527**

# %%
#Datos
radio9,velc9 = np.loadtxt("4527.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc9 = velc9*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R9 = np.linspace(radio9[1],radio9[-1],num=len(radio9))  #[kpc]

#Grafica.
plt.plot(R9,Velc9*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 4527")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc4527.png")

# %% [markdown]
# **4565**

# %%
#Datos
radio10,velc10 = np.loadtxt("4565.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc10 = velc10*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R10 = np.linspace(radio10[1],radio10[-1],num=len(radio10))  #[kpc]

#Grafica.
plt.plot(R10,Velc10*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 4565")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc4565.png")

# %% [markdown]
# # **GALAXIAS TIPO Sc**

# %% [markdown]
# **0253**

# %%
#Datos
radio11,velc11 = np.loadtxt("0253.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc11 = velc11*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R11 = np.linspace(radio11[1],radio11[-1],num=len(radio11))  #[kpc]

#Grafica.
plt.plot(R11,Velc11*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 0253")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc0253.png")

# %% [markdown]
# 0598

# %%
#Datos
radio12,velc12 = np.loadtxt("0598.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc12 = velc12*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R12 = np.linspace(radio12[1],radio12[-1],num=len(radio12))  #[kpc]

#Grafica.
plt.plot(R12,Velc12*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 0598")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc0598.png")

# %% [markdown]
# **0660**

# %%
#Datos
radio13,velc13 = np.loadtxt("0660.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc13 = velc13*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R13 = np.linspace(radio13[1],radio13[-1],num=len(radio13))  #[kpc]

#Grafica.
plt.plot(R13,Velc13*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC0660")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc0660.png")

# %% [markdown]
# **2403**

# %%
#Datos
radio14,velc14= np.loadtxt("2403.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc14 = velc14*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R14 = np.linspace(radio14[1],radio14[-1],num=len(radio14))  #[kpc]

#Grafica.
plt.plot(R14,Velc14*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 2403")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc2403.png")

# %% [markdown]
# **0342**

# %%
#Datos
radio15,velc15 = np.loadtxt("0342.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc15 = velc15*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R15 = np.linspace(radio15[1],radio15[-1],num=len(radio15))  #[kpc]

#Grafica.
plt.plot(R15,Velc15*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 0342")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc0342.png")

# %% [markdown]
# **2903**

# %%
#Datos
radio16,velc16 = np.loadtxt("2903.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc16 = velc16*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R16 = np.linspace(radio16[1],radio16[-1],num=len(radio16))  #[kpc]

#Grafica.
plt.plot(R16,Velc16*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 2903")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc2903.png")

# %% [markdown]
# **3079**

# %%
#Datos
radio17,velc17 = np.loadtxt("3079.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc17 = velc17*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R17 = np.linspace(radio17[1],radio17[-1],num=len(radio17))  #[kpc]

#Grafica.
plt.plot(R17,Velc17*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 3079")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc3079.png")

# %% [markdown]
# **3672**

# %%
#Datos
radio18,velc18 = np.loadtxt("3672.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc18 = velc18*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R18 = np.linspace(radio18[1],radio18[-1],num=len(radio18))  #[kpc]

#Grafica.
plt.plot(R18,Velc18*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 3672")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc3672.png")

# %% [markdown]
# **4062**

# %%
#Datos
radio19,velc19 = np.loadtxt("4062.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc19 = velc19*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R19 = np.linspace(radio19[1],radio19[-1],num=len(radio19))  #[kpc]

#Grafica.
plt.plot(R19,Velc19*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 4062")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc4062.png")

# %% [markdown]
# **4096**

# %%
#Datos
radio20,velc20 = np.loadtxt("4096.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc20 = velc20*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R20 = np.linspace(radio20[1],radio20[-1],num=len(radio20))  #[kpc]

#Grafica.
plt.plot(R20,Velc20*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 4096")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc4096.png")

# %% [markdown]
# **4303**

# %%
#Datos
radio21,velc21 = np.loadtxt("4303.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc21 = velc21*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R21 = np.linspace(radio21[1],radio21[-1],num=len(radio21))  #[kpc]

#Grafica.
plt.plot(R21,Velc21*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 4303")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc4303.png")

# %% [markdown]
# **4321**

# %%
#Datos
radio22,velc22 = np.loadtxt("4321.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc22 = velc22*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R22 = np.linspace(radio22[1],radio22[-1],num=len(radio22))  #[kpc]

#Grafica.
plt.plot(R22,Velc22*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 4321")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc4321.png")

# %% [markdown]
# **5033**

# %%
#Datos
radio23,velc23 = np.loadtxt("5033.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc23 = velc23*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R23 = np.linspace(radio23[1],radio23[-1],num=len(radio23))  #[kpc]

#Grafica.
plt.plot(R23,Velc23*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 5033")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc5033.png")

# %% [markdown]
# **5194**

# %%
#Datos
radio24,velc24 = np.loadtxt("5194.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc24 = velc24*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R24 = np.linspace(radio24[1],radio24[-1],num=len(radio24))  #[kpc]

#Grafica.
plt.plot(R24,Velc24*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 5194")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc5194.png")

# %% [markdown]
# **5457**

# %%
#Datos
radio25,velc25 = np.loadtxt("5457.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc25 = velc25*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R25 = np.linspace(radio25[1],radio25[-1],num=len(radio25))  #[kpc]

#Grafica.
plt.plot(R25,Velc25*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 5457")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc5457.png")

# %% [markdown]
# **5907**

# %%
#Datos
radio26,velc26 = np.loadtxt("5907.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc26 = velc26*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R26 = np.linspace(radio26[1],radio26[-1],num=len(radio26))  #[kpc]

#Grafica.
plt.plot(R26,Velc26*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 5907")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc5907.png")

# %% [markdown]
# **6946**

# %%
#Datos
radio27,velc27 = np.loadtxt("6946.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc27 = velc27*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R27 = np.linspace(radio27[1],radio27[-1],num=len(radio27))  #[kpc]

#Grafica.
plt.plot(R27,Velc27*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 6946")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc6946.png")

# %% [markdown]
# # **GALAXIAS Sd**

# %% [markdown]
# **3495**

# %%
#Datos
radio28,velc28 = np.loadtxt("3495.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc28 = velc28*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R28 = np.linspace(radio28[1],radio28[-1],num=len(radio28))  #[kpc]

#Grafica.
plt.plot(R28,Velc28*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("3495")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.ylim(0,300)
plt.savefig("ngc3495.png")

# %% [markdown]
# # **GALAXIAS TIPO Sab**

# %% [markdown]
# **4736**

# %%
#Datos
radio29,velc29 = np.loadtxt("4736.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc29 = velc29*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R29 = np.linspace(radio29[1],radio29[-1],num=len(radio29))  #[kpc]

#Grafica.
plt.plot(R29,Velc29*(3.086e16/1.0001044887813144157), ".", markersize=1,color="purple")

plt.title("NGC 4736")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc4736.png")

# %% [markdown]
# **4569**

# %%
#Datos
radio30,velc30 = np.loadtxt("4569.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc30 = velc30*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R30 = np.linspace(radio30[1],radio30[-1],num=len(radio30))  #[kpc]

#Grafica.
plt.plot(R30,Velc30*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 4569")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc4569.png")

# %% [markdown]
# # **GALAXIAS TIPO Sbc**

# %% [markdown]
# **1808**

# %%
#Datos
radio31,velc31 = np.loadtxt("1808.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc31 = velc31*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R31 = np.linspace(radio31[1],radio31[-1],num=len(radio31))  #[kpc]

#Grafica.
plt.plot(R31,Velc31*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 1808")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc1808.png")

# %% [markdown]
# **3521**

# %%
#Datos
radio32,velc32 = np.loadtxt("3521.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc32 = velc32*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R32 = np.linspace(radio32[1],radio32[-1],num=len(radio32))  #[kpc]

#Grafica.
plt.plot(R32,Velc32*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 3521")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc3521.png")

# %% [markdown]
# **4258**

# %%
#Datos
radio33,velc33 = np.loadtxt("4258.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc33 = velc33*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R33 = np.linspace(radio33[1],radio33[-1],num=len(radio33))  #[kpc]

#Grafica.
plt.plot(R33,Velc33*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 4258")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc4258.png")

# %% [markdown]
# **6951**

# %%
#Datos
radio34,velc34 = np.loadtxt("6951.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc34 = velc34*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R34 = np.linspace(radio34[1],radio34[-1],num=len(radio34))  #[kpc]

#Grafica.
plt.plot(R34,Velc34*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 6951")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc6951.png")

# %% [markdown]
# **7331**

# %%
#Datos
radio35,velc35 = np.loadtxt("7331.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc35 = velc35*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R35 = np.linspace(radio35[1],radio35[-1],num=len(radio35))  #[kpc]

#Grafica.
plt.plot(R35,Velc35*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 7331")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc7331.png")

# %% [markdown]
# **5055**

# %%
#Datos
radio36,velc36 = np.loadtxt("5055.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc36 = velc36*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R36 = np.linspace(radio36[1],radio36[-1],num=len(radio36))  #[kpc]

#Grafica.
plt.plot(R36,Velc36*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("NGC 5055")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc5055.png")

# %% [markdown]
# # **GALAXIAS TIPO Scd**

# %% [markdown]
# **1003**

# %%
#Datos
radio37,velc37 = np.loadtxt("1003.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc37 = velc37*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R37 = np.linspace(radio37[1],radio37[-1],num=len(radio37))  #[kpc]

#Grafica.
plt.plot(R37,Velc37*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("NGC 1003")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc1003.png")

# %% [markdown]
# **3691**

# %%
#Datos
radio38,velc38 = np.loadtxt("3691.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc38 = velc38*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R38 = np.linspace(radio38[1],radio38[-1],num=len(radio38))  #[kpc]

#Grafica.
plt.plot(R38,Velc38*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("3691")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
#plt.ylim(0,300)
plt.savefig("ngc3691.png")

# %% [markdown]
# # **GALAXIAS TIPO SBab**

# %% [markdown]
# **4448**

# %%
#Datos
radio45,velc45 = np.loadtxt("4448.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc45=velc45*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R45 = np.linspace(radio45[1],radio45[-1],num=len(radio45))  #[kpc]

#Grafica.
plt.plot(R45,Velc45*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.title("NGC 4448")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc4448.png")

# %% [markdown]
# # **GALAXIAS TIPO SBb**

# %% [markdown]
# **1097**

# %%
#Datos
radio39,velc39 = np.loadtxt("1097.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc39 = velc39*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R39 = np.linspace(radio39[1],radio39[-1],num=len(radio39))  #[kpc]

#Grafica.
plt.plot(R39,Velc39*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("1097")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
#plt.ylim(0,300)
plt.savefig("ngc1097.png")

# %% [markdown]
# **1365**

# %%
#Datos
radio40,velc40 = np.loadtxt("1365.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc40 = velc40*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R40 = np.linspace(radio40[1],radio40[-1],num=len(radio40))  #[kpc]

#Grafica.
plt.plot(R40,Velc40*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")

plt.title("1365")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
#plt.ylim(0,300)
plt.savefig("ngc1365.png")

# %% [markdown]
# **6674**

# %%
radio41,velc41 = np.loadtxt("6674.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc41 = velc41*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R41 = np.linspace(radio41[1],radio41[-1],num=len(radio41))  #[kpc]

#Grafica.
plt.plot(R41,Velc41*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("6674")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
#plt.ylim(0,300)
plt.savefig("ngc6674.png")

# %% [markdown]
# # **GALAXIAS TIPO SBc**

# %% [markdown]
# **2855**

# %%
#Datos
radio42,velc42 = np.loadtxt("2855.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc42=velc42*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R42 = np.linspace(radio42[1],radio42[-1],num=len(radio42))  #[kpc]

#Grafica.
plt.plot(R42,Velc42*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.title("UGC 2855")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc2855.png")

# %% [markdown]
# **3198**

# %%
#Datos
radio43,velc43 = np.loadtxt("3198.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc43=velc43*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R43 = np.linspace(radio43[1],radio43[-1],num=len(radio43))  #[kpc]

#Grafica.
plt.plot(R43,Velc43*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")
plt.title("NGC 3198")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc3198.png")

# %% [markdown]
# **5236**

# %%
#Datos
radio44,velc44 = np.loadtxt("3198.dat",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Cambio de unidad a las velocidades.
Velc44=velc44*(1.0001044887813144157/3.086e16) #[kpc/s]

#Radios
R44 = np.linspace(radio44[1],radio44[-1],num=len(radio44))  #[kpc]

#Grafica.
plt.plot(R44,Velc44*(3.086e16/1.0001044887813144157), ".", markersize=1, color="purple")
plt.title("NGC 5236")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("ngc5236.png")

# %% [markdown]
# # GRAFICAS DE TODAS LAS GALAXIAS

# %%
#Para las Sb
plt.plot(R,Velc*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R1,Velc1*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R2,Velc2*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R3,Velc3*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R4,Velc4*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R5,Velc5*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R6,Velc6*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R7,Velc7*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R8,Velc8*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R9,Velc9*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R10,Velc10*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.plot(R31,Velc31*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R32,Velc32*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R33,Velc33*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R34,Velc34*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R35,Velc35*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R36,Velc36*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("Galaxias tipo Sb")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("sb.png")

# %%
#Para las Sc
plt.plot(R11,Velc11*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R12,Velc12*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R13,Velc13*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R14,Velc14*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R15,Velc15*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R16,Velc16*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R17,Velc17*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R18,Velc18*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R19,Velc19*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R20,Velc20*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R21,Velc21*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R22,Velc22*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R23,Velc23*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R24,Velc24*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R25,Velc25*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R26,Velc26*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R27,Velc27*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")


plt.plot(R37,Velc37*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R38,Velc38*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("Galaxias tipo Sc")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("sc.png")

# %%
#Para las Sab
plt.plot(R29,Velc29*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R30,Velc30*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("Galaxias tipo Sab")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.savefig("sab.png")

# %%
#Para las Sbc
plt.plot(R31,Velc31*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R32,Velc32*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R33,Velc33*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R34,Velc34*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R35,Velc35*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R36,Velc36*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("Galaxias tipo Sbc")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.savefig("sbc.png")

# %%
#Para las Scd
plt.plot(R37,Velc37*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R38,Velc38*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("Galaxias tipo Scd")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.savefig("scd.png")

# %%
#Para las SB
plt.plot(R39,Velc39*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R40,Velc40*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R41,Velc41*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R42,Velc42*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R43,Velc43*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R44,Velc44*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R45,Velc45*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")


plt.title("Galaxias tipo SBab, SBb y SBc")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.xlim(0,30)
plt.ylim(0,400)
plt.savefig("sB.png")

# %%
#Para las SBb
plt.plot(R39,Velc39*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R40,Velc40*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R41,Velc41*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("Galaxias tipo SBb")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
plt.savefig("sBb.png")

# %%
#Para las SBc
plt.plot(R42,Velc42*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R43,Velc43*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")
plt.plot(R44,Velc44*(3.086e16/1.0001044887813144157), ".", markersize=2, color="purple")

plt.title("Galaxias tipo SBc")
plt.xlabel("R [kpc]")
plt.ylabel("Vc [km/s]")
#plt.ylim(0,300)
plt.savefig("sBc.png")
