# %%
#Librerias
import numpy as np
from scipy.optimize import curve_fit
import scipy.integrate as integrate
import scipy.special as special
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Datos.
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e24fd77e-6fd9-496a-a7bb-bb8e635e3739" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e24fd77e-6fd9-496a-a7bb-bb8e635e3739">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **NGC 224**

# %%
#Datos
x,y = np.loadtxt("NGC_224.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 224 en el óptico")
plt.xlabel("$\lambda$ [A]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 224 OPT")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # NGC 253

# %%
#Datos
x,y = np.loadtxt("NGC_253.txt",usecols=(0,3),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 253 en NII")
plt.xlabel("$\lambda$ [$\mu m$]")
plt.ylabel("$F_{\lambda}$ [Jy]")
plt.savefig("NGC 253 NII")

# %% [markdown]
# # **NGC 891**

# %%
#Datos
x5,y5 = np.loadtxt("NGC_891.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x5,y5, "-", color="purple")
plt.title("Espectro de NGC 891 en el óptico")
plt.xlabel("$\lambda$ [A]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 891 OPT")

# %% [markdown]
# # **NGC 1068**

# %%
#Datos
x9,y9 = np.loadtxt("NGC_1068_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x9,y9, "-", color="purple")
plt.title("Espectro de NGC 1068 en el óptico")
plt.xlabel("$\lambda$ [A]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 1068 OPT")

# %% [markdown]
# # **NGC 2590**

# %%
#Datos
x12,y12 = np.loadtxt("NGC_2590_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x12,y12, "-", color="purple")
plt.title("Espectro de NGC 2590 en el óptico")
plt.xlabel("$\lambda$ [A]")
plt.ylabel("$F_{\lambda}$ [Counts]")
plt.ylim(0,6000)
plt.savefig("NGC 2590 OPT")

# %% [markdown]
# # **NGC 2708**

# %%
#Datos
x13,y13 = np.loadtxt("NGC_2708_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x13,y13, "-", color="purple")
plt.title("Espectro de NGC 2708 en el óptico")
plt.xlabel("$\lambda$ [A]")
plt.ylabel("$F_{\lambda}$ [Counts]")
plt.savefig("NGC 2708 OPT")

# %% [markdown]
# # **NGC 2841**

# %%
#Datos
x14,y14 = np.loadtxt("NGC_2841_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x14,y14, "-", color="purple")
plt.title("Espectro de NGC 2841 en el óptico")
plt.xlabel("$\lambda$ [A]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 2841 OPT")

# %% [markdown]
# # **NGC 598**

# %%
#Datos
x17,y17 = np.loadtxt("NGC_0598_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x17,y17, "-", color="purple")
plt.title("Espectro de NGC 0598 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 598 OPT")

# %% [markdown]
# # **NGC 0660**

# %%
#Datos
x19,y19 = np.loadtxt("NGC_0660_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x19,y19, "-", color="purple")
plt.title("Espectro de NGC 0660 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 660 OPT")

# %% [markdown]
# # **NGC 2403**

# %%
#Datos
x20,y20 = np.loadtxt("NGC_2403_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x20,y20, "-", color="purple")
plt.title("Espectro de NGC 2403 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 2403 OPT")

# %% [markdown]
# # **IC 0342**

# %%
#Datos
x23,y23 = np.loadtxt("IC_0342_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x23,y23, "-", color="purple")
plt.title("Espectro de IC 342 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("IC 342 OPT")

# %% [markdown]
# # **NGC 2903**

# %%
#Datos
x24,y24 = np.loadtxt("NGC_2903_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x24,y24, "-", color="purple")
plt.title("Espectro de NGC 2903 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 2903 OPT")

# %% [markdown]
# # **NGC 3079**

# %%
#Datos
x26,y26 = np.loadtxt("NGC_3079_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,3))
plt.plot(x26,y26, "-", color="purple")
plt.title("Espectro de NGC 3079 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 3079 OPT")

# %% [markdown]
# # **NGC 3672**

# %%
#Datos
x28,y28 = np.loadtxt("NGC_3672_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,3))
plt.plot(x28,y28, "-", color="purple")
plt.title("Espectro de NGC 3672 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [Counts]")
plt.savefig("NGC 3672 OPT")

# %% [markdown]
# # **NGC 4062**

# %%
#Datos
x29,y29 = np.loadtxt("NGC_4062_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,3))
plt.plot(x29,y29, "-", color="purple")
plt.title("Espectro de NGC 4062 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 4062 OPT")

# %% [markdown]
# # **NGC 4096**

# %%
#Datos
x30,y30 = np.loadtxt("NGC_4096_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,3))
plt.plot(x30,y30, "-", color="purple")
plt.title("Espectro de NGC 4096 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [Counts]")
plt.savefig("NGC 4096 OPT")

# %% [markdown]
# # **NGC 4303**

# %%
#Datos
x31,y31 = np.loadtxt("NGC_4303_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,3))
plt.plot(x31,y31, "-", color="purple")
plt.title("Espectro de NGC 4303 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 43O3 OPT")

# %% [markdown]
# #**NGC 4321**

# %%
#Datos
x33,y33 = np.loadtxt("NGC_4321_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,3))
plt.plot(x33,y33, "-", color="purple")
plt.title("Espectro de NGC 4321 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 4321 OPT")

# %% [markdown]
# # NGC 1003

# %%
#Datos
x34,y34 = np.loadtxt("NGC_1003_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x34,y34, "-", color="purple")
plt.title("Espectro de NGC 1003 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 1003 OPT")

# %% [markdown]
# # NGC 1365

# %%
#Datos
x35,y35 = np.loadtxt("NGC_1365_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x35,y35, "-", color="purple")
plt.title("Espectro de NGC 1365 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [counts]")
plt.savefig("NGC 1365 OPT")

# %% [markdown]
# # NGC 1808

# %%
#Datos
x36,y36 = np.loadtxt("NGC_1808_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x36,y36, "-", color="purple")
plt.title("Espectro de NGC 1808 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 1808 OPT")

# %% [markdown]
# # NGC 2841

# %%
#Datos
x37,y37 = np.loadtxt("NGC_2841_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,3))
plt.plot(x37,y37, "-", color="purple")
plt.title("Espectro de NGC 2841 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 2841 OPT")

# %% [markdown]
# # UGC 2855

# %%
#Datos
x38,y38 = np.loadtxt("UGC_2855.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x38,y38, "-", color="purple")
plt.title("Espectro de UGC 2855 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("UGC 2855 OPT")

# %% [markdown]
# # NGC 2903

# %%
#Datos
x39,y39 = np.loadtxt("NGC_2903_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,3))
plt.plot(x39,y39, "-", color="purple")
plt.title("Espectro de NGC 2903 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 2903 OPT")

# %% [markdown]
# # NGC 3031

# %%
#Datos
x40,y40 = np.loadtxt("NGC_3031_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x40,y40, "-", color="purple")
plt.title("Espectro de NGC 3031 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 3031 OPT")

# %% [markdown]
# # NGC 3034

# %%
#Datos
x41,y41 = np.loadtxt("NGC_3034_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x41,y41, "-", color="purple")
plt.title("Espectro de NGC 3034 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 3034 OPT")

# %% [markdown]
# # NGC 3079

# %%
#Datos
x42,y42 = np.loadtxt("NGC_3079_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x42,y42, "-", color="purple")
plt.title("Espectro de NGC 3079 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 3079 OPT")

# %% [markdown]
# # NGC 7331

# %%
#Datos
x43,y43 = np.loadtxt("NGC_7331_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x43,y43, "-", color="purple")
plt.title("Espectro de NGC 7331 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 7331 OPT")

# %% [markdown]
# # NGC 1097

# %%
#Datos
x,y = np.loadtxt("NGC_1097.txt",usecols=(0,3),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 1097 en NII")
plt.xlabel("$\lambda$ [$\mu m$]")
plt.ylabel("$F_{\lambda}$ [Jy]")
plt.savefig("NGC 1097 NII")

# %% [markdown]
# # NGC 1417

# %%
#Datos
x,y = np.loadtxt("NGC_1417.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 1417 en HI")
plt.xlabel("$\lambda$ [km $s^-1$]")
plt.ylabel("$F_{v}$ [Jy]")
plt.savefig("NGC 1417 HI")

# %% [markdown]
# # UGC 3691

# %%
#Datos
x,y = np.loadtxt("UGC_3691.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de UGC 3691 en el óptico")
plt.xlabel("$\lambda$ [A]")
plt.ylabel("$F_{v}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("UGC 3691 OPT")

# %% [markdown]
# # NGC 4945

# %%
#Datos
x,y = np.loadtxt("NGC_4945.txt",usecols=(0,3),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 4945 en NII")
plt.xlabel("$\lambda$ [$\mu m$]")
plt.ylabel("$F_{\lambda}$ [Jy]")
plt.savefig("NGC 4945 NII")

# %% [markdown]
# # NGC 6674

# %%
#Datos
x,y = np.loadtxt("NGC_6674.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 6674 en HI")
plt.xlabel("v [km $s^-1$]")
plt.ylabel("$F_{v}$ [mJy]")
plt.savefig("NGC 6674 HI")

# %% [markdown]
# # NGC 4527

# %%
#Datos
x,y = np.loadtxt("NGC_4527_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 4527 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 4527 OPT")

# %% [markdown]
# # NGC 4565

# %%
#Datos
x,y = np.loadtxt("NGC_4565_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 4565 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 4565 OPT")

# %% [markdown]
# # NGC 4569

# %%
#Datos
x,y = np.loadtxt("NGC_4569_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 4569 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 4569 OPT")

# %% [markdown]
# # NGC 4631

# %%
#Datos
x,y = np.loadtxt("NGC_4631_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 4631 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 4631 OPT")

# %% [markdown]
# # NGC 4736

# %%
#Datos
x,y = np.loadtxt("NGC_4736_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 4736 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 4736 OPT")

# %% [markdown]
# # NGC 5033

# %%
#Datos
x,y = np.loadtxt("NGC_5033_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 5033 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 5033 OPT")

# %% [markdown]
# # NGC 5055

# %%
#Datos
x,y = np.loadtxt("NGC_5055_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 5055 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 5055 OPT")

# %% [markdown]
# # NGC 5194

# %%
#Datos
x,y = np.loadtxt("NGC_5194_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 5194 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 5194 OPT")

# %% [markdown]
# # NGC 5236

# %%
#Datos
x,y = np.loadtxt("NGC_5236_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 5236 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [Counts]")
plt.ylim(0,4500)
plt.savefig("NGC 5236 OPT")

# %% [markdown]
# # NGC 5457

# %%
#Datos
x,y = np.loadtxt("NGC_5457_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 5457 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 5457 OPT")

# %% [markdown]
# # NGC 5907

# %%
#Datos
x,y = np.loadtxt("NGC_5907_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 5907 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 5907 OPT")

# %% [markdown]
# # NGC 6946

# %%
#Datos
x,y = np.loadtxt("NGC_6946_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 6946 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("[Flux per angstrom]")
plt.savefig("NGC 6946 OPT")

# %% [markdown]
# # NGC 6951

# %%
#Datos
x,y = np.loadtxt("NGC_6951_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 6951 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 6951 OPT")

# %% [markdown]
# # NGC 3198

# %%
#Datos
x,y = np.loadtxt("NGC_3198_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 3198 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 3198 OPT")

# %% [markdown]
# # NGC 3495

# %%
#Datos
x,y = np.loadtxt("NGC_3495_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 3495 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 3495 OPT")

# %% [markdown]
# # NGC 3521

# %%
#Datos
x,y = np.loadtxt("NGC_3521_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 3521 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 3521 OPT")

# %% [markdown]
# # NGC 3628

# %%
#Datos
x,y = np.loadtxt("NGC_3628_OP.txt",usecols=(0,1),unpack=True,comments="#") # radio(r) = [kpc] & Velocidad(Vr) = [Km/s]

#Grafica.
plt.figure(figsize=(10,4))
plt.plot(x,y, "-", color="purple")
plt.title("Espectro de NGC 3628 en el óptico")
plt.xlabel("$\lambda$ [$A$]")
plt.ylabel("$F_{\lambda}$ [erg $s^{-1}cm^{-2} A^{-1}$]")
plt.savefig("NGC 3628 OPT")
